# %% [markdown]
# <a href="https://colab.research.google.com/github/0Kyumy0/FirstCodes_DataScience/blob/Panda/basicOperationsPanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
filename = '/content/bostonHousing1978.csv'
df = pd.read_csv(filename)

# %%
# muestra los primeros 5 datos de la tabla
df.head()
# Out:
#       RM  LSTAT  PTRATIO  target
# 0  6.575   4.98     15.3    24.0
# 1  6.421   9.14     17.8    21.6
# 2  7.185   4.03     17.8    34.7
# 3  6.998   2.94     18.7    33.4
# 4  7.147   5.33     18.7    36.2

# %%
# muestra las últimas 5 filas
df.tail()
# Out:
#         RM  LSTAT  PTRATIO  target
# 501  6.593   9.67     21.0    22.4
# 502  6.120   9.08     21.0    20.6
# 503  6.976   5.64     21.0    23.9
# 504  6.794   6.48     21.0    22.0
# 505  6.030   7.88     21.0    11.9

# %%
# muestra los tipos de datos en cada columna
df.dtypes
# Out:
# RM         float64
# LSTAT      float64
# PTRATIO    float64
# target     float64
# dtype: object

# %%
# muestra el número de (filas, columnas) en el dataframe
df.shape
# Out:
# (506, 4)

# %%
# The info method gives the column datatypes and number of non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       506 non-null    float64
#  1   LSTAT    506 non-null    float64
#  2   PTRATIO  506 non-null    float64
#  3   target   506 non-null    float64
# dtypes: float64(4)
# memory usage: 15.9 KB
